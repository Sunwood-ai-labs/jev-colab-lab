# %% [markdown]
# # Kev-0.5B T4実測レポート
#
# 公開用に実行環境の識別情報・認証情報・送信履歴を除いたsanitized reportです。再実行コードは親フォルダの `kev_t4_inference.ipynb` と `t4_inference.py` を使用します。

# %%
# Values are copied from kev-t4-result.json after removing runtime/session metadata.
print('status=success')
print('gpu=Tesla T4, capability=7.5, total_memory_mb=14912.688')
print('torch=2.11.0+cu128, precision=float32')
print('load_s=1.9682, first_inference_s=0.7026, steady_mean_s=0.0501')
print('peak_allocated_mb=1946.746')
print('packed_vs_separate_max_abs_probability_difference=4.172325134277344e-07')
print('department=returns (returns=0.8493166566, shipping=0.1041532531, billing=0.0465301462)')
print('escalate_yes=0.6454819441')
print('frustration=[0.2562892437, 0.5911108851, 0.1525998712]')
# Out:
# status=success
# gpu=Tesla T4, capability=7.5, total_memory_mb=14912.688
# torch=2.11.0+cu128, precision=float32
# load_s=1.9682, first_inference_s=0.7026, steady_mean_s=0.0501
# peak_allocated_mb=1946.746
# packed_vs_separate_max_abs_probability_difference=4.172325134277344e-07
# department=returns (returns=0.8493166566, shipping=0.1041532531, billing=0.0465301462)
# escalate_yes=0.6454819441
# frustration=[0.2562892437, 0.5911108851, 0.1525998712]
