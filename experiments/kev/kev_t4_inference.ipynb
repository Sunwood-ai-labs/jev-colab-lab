# %% [markdown]
# # Kev-0.5B / Colab T4 推論
#
# このノートブックは、同じフォルダの `t4_inference.py` を実行します。公式コードは GitHub `v0.1.0`、アダプタは Hugging Face の immutable commit SHA で固定し、重みはリポジトリへ保存しません。
#
# 実行前に、ローカルの公式 Colab CLI から `/content/t4_inference.py` へスクリプトを upload してください。結果は `/content/kev-t4-result.json` に保存されます。

# %%
from pathlib import Path

script = Path('/content/t4_inference.py')
if not script.is_file():
    raise FileNotFoundError('upload experiments/kev/t4_inference.py to /content/t4_inference.py first')
exec(compile(script.read_text(encoding='utf-8'), str(script), 'exec'), {'__name__': '__main__'})
